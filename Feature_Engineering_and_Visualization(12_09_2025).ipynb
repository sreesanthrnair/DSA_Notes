# %% [markdown]
# <a href="https://colab.research.google.com/github/sreesanthrnair/DSA_Notes/blob/main/Feature_Engineering_and_Visualization(12_09_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##🛠️ Feature Engineering: Making Data Smarter
# Feature engineering is the process of transforming raw data into meaningful features that improve the predictive power of machine learning models. It includes:
# - Feature Creation: Deriving new features from existing ones (e.g., extracting “day of week” from a timestamp)
# - Feature Transformation: Scaling, normalizing, or encoding data for better model compatibility
# - Feature Selection: Choosing the most relevant features to reduce noise and overfitting
# - Handling Missing Data: Imputing missing values using mean, median, or more advanced methods
# - Dimensionality Reduction: Using techniques like PCA to simplify data without losing important information

# %% [markdown]
# ##📊 Visualization: Seeing the Story in Your Data
# Visualization helps you understand your features before and after engineering. It’s essential for:
# - Exploratory Data Analysis (EDA): Spotting trends, outliers, and distributions
# - Feature Correlation: Using heatmaps to identify relationships between variables
# - Distribution Checks: Histograms and box plots reveal skewness and variance
# - Dimensionality Insights: Visualizing PCA or t-SNE results to understand feature space
# - Model Interpretability: Tools like SHAP or partial dependence plots show how features affect predictions

# %% [markdown]
# ##📌 Discrete Data
# - Definition: Data that can only take specific, separate values.
# - Characteristics:
# - Countable
# - No fractions or decimals
# - Often whole numbers
# - Examples:
# - Number of students in a class (e.g., 25, 30)
# - Number of cars in a parking lot
# - Dice roll outcomes (1 to 6)
# - Visualized with: Bar charts, pie charts
#
# ##📌 Continuous Data
# - Definition: Data that can take any value within a range.
# - Characteristics:
# - Measurable
# - Can include fractions and decimals
# - Infinite possibilities between two values
# - Examples:
# - Height (e.g., 170.5 cm)
# - Temperature (e.g., 36.6°C)
# - Time (e.g., 10.75 seconds)
# - Visualized with: Histograms, line plots, scatter plots

# %% [markdown]
# #🧠 Key Techniques for Feature Extraction
# ##1. Statistical Methods
# - Use basic statistics to summarize data.
# - Examples: Mean, median, standard deviation, correlation, regression coefficients.
# - Useful for time series, sensor data, and tabular datasets.
# ##2. Dimensionality Reduction
# - Simplifies data by reducing the number of features while preserving important information.
# - Techniques:
# - PCA (Principal Component Analysis): Projects data onto directions of maximum variance.
# - LDA (Linear Discriminant Analysis): Maximizes class separability.
# - t-SNE: Visualizes high-dimensional data in 2D or 3D space.
# ##3. Feature Extraction for Text Data
# - Converts unstructured text into numerical features.
# - Techniques:
# - Bag of Words (BoW): Counts word occurrences.
# - TF-IDF (Term Frequency–Inverse Document Frequency): Weighs words by importance.
# - Word Embeddings: Captures semantic meaning (e.g., Word2Vec, GloVe, BERT).
# ##4. Feature Extraction for Image Data
# - Transforms pixel data into meaningful patterns.
# - Techniques:
# - Edge detection (e.g., Sobel, Canny)
# - Histogram of Oriented Gradients (HOG)
# - Convolutional Neural Networks (CNNs): Automatically learn hierarchical features.
# ##5. Feature Extraction for Audio and Signal Data
# - Converts waveforms into structured features.
# - Techniques:
# - MFCC (Mel-frequency cepstral coefficients): Common in speech recognition.
# - Spectrograms: Visual representation of frequency over time.
# ##6. Autoencoders
# - Neural networks that learn compressed representations of data.
# - Useful for unsupervised feature extraction and anomaly detection.

# %% [markdown]
#  Feature Engineering, Feature Selection, and Feature Extraction
# | Aspect                  | Feature Engineering                            | Feature Selection                              | Feature Extraction                              |
# |------------------------|------------------------------------------------|------------------------------------------------|-------------------------------------------------|
# | **Purpose**            | Create or modify features using domain knowledge | Choose the most relevant features               | Transform features into a new set               |
# | **Input**              | Raw or existing data                           | Existing features                               | Original features                               |
# | **Output**             | Enhanced or new features                       | Subset of original features                     | New transformed features                        |
# | **Techniques**         | Binning, scaling, encoding, interaction terms  | RFE, Lasso, tree-based importance               | PCA, LDA, autoencoders                          |
# | **Data Dependency**    | Often manual and domain-specific               | Requires labeled data (for supervised methods)  | Can be supervised or unsupervised               |
# | **Interpretability**   | High (features are human-readable)             | High (original features retained)               | Often low (transformed features are abstract)   |
# | **Goal**               | Improve data quality and relevance             | Reduce dimensionality and avoid overfitting     | Capture deeper patterns and structure           |
#
# 

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
month=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
visits=[12500,14200,16800,18500,21000,19700,22300,23400,17200,15400,24600,31500]

# %%
plt.plot(month,visits)

# %% [markdown]
# ### Markers
#
# | Marker | Description |
# | :--- | :--- |
# | '.' | point |
# | 'o' | circle |
# | 'v' | triangle down |
# | '^' | triangle up |
# | 's' | square |
# | 'p' | pentagon |
# | '*' | star |
# | '+' | plus |
# | 'x' | x |
# | 'D' | diamond |
#
# *
#
# ### Line Styles
#
# | Line Style | Description |
# | :--- | :--- |
# | '-' | solid line |
# | '--' | dashed line |
# | '-.' | dash-dot line |
# | ':' | dotted line |
#
# *
#
# ### Colors
#
# Colors can be specified using a single-letter shorthand or by full color names, Hex codes, or RGB tuples.
#
# | Shorthand | Color |
# | :--- | :--- |
# | 'b' | blue |
# | 'g' | green |
# | 'r' | red |
# | 'c' | cyan |
# | 'm' | magenta |
# | 'y' | yellow |
# | 'k' | black |
# | 'w' | white |
#
# *Examples:*
# * You can use a full color name: color = 'skyblue'
# * You can use a Hex code: color = '#FF5733'
# * You can use a (R, G, B) tuple: color = (0.5, 0.2, 0.8)

# %%
plt.plot(month,visits,'d-',color='purple')

# %%
months = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

visits = [
    120, 105, 152, 138, 160, 145,
    173, 180, 167, 192, 200, 225
]

conversion_rates = [
    2.5, 3.1, 2.8, 3.0, 3.5, 2.9,
    3.2, 3.6, 3.0, 3.8, 4.0, 4.2
]

# %%
plt.plot(month,visits,'o-',color='pink')
plt.plot(month,conversion_rates,'s--',color='orange')

avg_visits=np.mean(visits)
plt.axhline(y=avg_visits,color='red',linestyle='--')

max_convertion_rate=np.max(conversion_rates)
plt.axvline(x=max_convertion_rate,color='yellow',linestyle='--')


plt.title('Monthly Subscibers')
plt.xlabel('Month')
plt.ylabel('Subscribers')
plt.legend(['Visits','Conversion Rate'])
plt.show()

# %% [markdown]
# ##plt.bar
#
# | Argument | Description | Common Values & Examples |
# | :--- | :--- | :--- |
# | *width* | The width of the bars. | A float. width=0.8 (default), width=0.5 |
# | *color* | The color of the bars. | A single color, a list of colors, or a short code. color='skyblue', color=['r', 'g', 'b'], color='c' |
# | *align* | The alignment of the bars. | 'center' (default) or 'edge' |
# | *label* | A label for the bar(s) to be displayed in a legend. | A string. label='Website Visits' |
# | *tick_label* | The labels for the x-axis ticks. | A list of strings. tick_label=['Jan', 'Feb', 'Mar'] |
# | *edgecolor* | The color of the bar's outline. | A single color or a list of colors. edgecolor='black', edgecolor='k' |
# | *hatch* | A pattern to fill the bars. | '-', '+', 'x', '/', '\\', 'o', '.', '*' |
# | *bottom* | The y-coordinate of the bar's base. Useful for stacked bar charts. | A scalar or a list of scalars. bottom=y_base |

# %%
plt.bar(month,visits,color=['red','black','#98989a'])
# Out:
# <BarContainer object of 12 artists>

# %%
plt.figure(figsize=(5,5))
plt.bar(month,visits,color=('black'))
sales=[15,18,20,25,30,28,22,24,27,32,35,40]
plt.bar(month,sales,color='orange')
plt.xticks(rotation=45)


plt.title('Monthly Subscribers')
plt.xlabel('Month')
plt.ylabel('Subscribes')
plt.legend(['Visits','Sales'])
plt.tight_layout()

# %%
plt.figure(figsize=(5,5))
plt.barh(month,visits,color='black',edgecolor='orange')
sales=[15,18,20,25,30,28,22,24,27,32,35,40]
plt.barh(month,sales,color='purple',hatch='+')
plt.xticks(rotation=45)


plt.title('Monthly Subscribers')
plt.xlabel('Month')
plt.ylabel('Subscribes')
plt.legend(['Visits','Sales'])
plt.tight_layout()

# %% [markdown]
# ## plt.scatter
#
# plt.scatter(x, y, **kwargs)
#
#
#   - x: A sequence of scalars representing the x-coordinates of the points.
#   - y: A sequence of scalars representing the y-coordinates of the points.
#
# -----
#
# ### Key Arguments and Values
#
# | Argument | Description | Common Values & Examples |
# | :--- | :--- | :--- |
# | *s* | The size of the markers in points squared. | A single float or a list of floats. s=50, s=[20, 40, 60, ...] |
# | *c* | The color of the markers. | A single color, a list of colors, or a column of data for a color map. c='skyblue', c=['r', 'g', 'b'], c=visits |
# | *marker* | The marker style. | A string. marker='o', marker='s', marker='^' |
# | *alpha* | The transparency of the markers. | A float between 0 (fully transparent) and 1 (fully opaque). alpha=0.5 |
# | *edgecolor* | The color of the marker's outline. | A single color or a list of colors. edgecolor='black', edgecolor='none' |
# | *label* | A label for the markers to be displayed in a legend. | A string. label='Data Points' |
# | *cmap* | The colormap to use if c is a list of numbers. | cmap='viridis', cmap='plasma', cmap='inferno' |
#
# -----

# %%
study_hours = [2.5, 3.2, 5.1, 1.8, 4.5, 6.0, 3.5, 7.8, 1.2, 5.5, 4.0, 6.5, 2.0, 8.1, 4.8]
exam_scores = [65, 73, 88, 55, 80, 92, 75, 95, 50, 85, 78, 90, 60, 98, 82]

# %%
plt.figure(figsize=(5,3))
plt.scatter(study_hours, exam_scores,c = exam_scores, cmap = 'viridis')
plt.grid(True)
plt.title('Hours vs. Scores')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###plt.hist
#
# The most common way to use plt.hist is to provide a single dataset.
#
# plt.hist(x, **kwargs)
#
# x: An array or sequence of values representing the data you want to plot.

# %% [markdown]
# ### Key Arguments and Values
#
# | Argument | Description | Common Values & Examples |
# | :--- | :--- | :--- |
# | *bins* | The number of bins or the bin edges. | An integer (bins=20), a sequence of scalars (bins=[0, 10, 20, 30]), or a string (bins='auto'). |
# | *range* | The lower and upper range for the bins. | A tuple (min_val, max_val). range=(0, 100) |
# | *density* | If True, the histogram shows probability density. | A boolean. density=True |
# | *weights* | An array of weights for each data point. | A list or array of floats. weights=my_weights |
# | *cumulative*| If True, the histogram is computed as a cumulative distribution function (CDF). | A boolean. cumulative=True |
# | *histtype*| The type of histogram to draw. | 'bar' (default), 'barstacked', 'step', 'stepfilled' |
# | *color* | The color of the histogram bars. | A single color, a list of colors, or a short code. color='skyblue', color='g' |
# | *label* | A label for the histogram to be displayed in a legend. | A string. label='Exam Scores' |
# | *rwidth* | The relative width of the bars as a fraction of the bin width. | A float between 0 and 1. rwidth=0.8 |
# | *edgecolor* | The color of the bar's outline. | A single color. edgecolor='black' |
#
# -----

# %%
steps1=np.random.randint(500,1000,10)
steps2=np.random.randint(1000,5000,30)
steps3=np.random.randint(5000,14000,20)
steps = np.concatenate([steps1, steps2, steps3])

plt.hist(steps, color='skyblue', edgecolor='k', bins=6)
# Out:
# (array([27., 13.,  3.,  7.,  5.,  5.]),
#  array([  678.        ,  2807.33333333,  4936.66666667,  7066.        ,
#          9195.33333333, 11324.66666667, 13454.        ]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# ### plt.pie
#
# The most common way to use plt.pie is to provide the data to be plotted.
#
# python
# plt.pie(x, **kwargs)
#
#
#   * x: An array or sequence of values representing the size of each slice.
#
# -----
#
# ### Key Arguments and Values
#
# | Argument | Description | Common Values & Examples |
# | :--- | :--- | :--- |
# | *labels* | A sequence of strings to label each slice. | labels=['A', 'B', 'C'] |
# | *colors* | A sequence of colors for each slice. | colors=['red', 'blue', 'green'] |
# | *explode* | A sequence of values to "explode" (separate) a slice. | explode=(0, 0.1, 0, 0) to separate the second slice. |
# | *autopct* | A format string to display the percentage within each slice. | autopct='%1.1f%%', autopct='%.0f%%' |
# | *shadow* | If True, draws a shadow behind the pie chart. | A boolean. shadow=True |
# | *startangle* | Rotates the entire chart by a specified angle. | A float. startangle=90 (starts the first slice at the top) |
# | *radius* | The radius of the pie chart. | A float. radius=1.2 |
# | *counterclock* | Specifies the direction of the slices. | A boolean. counterclock=False for clockwise. |
# | *wedgeprops* | A dictionary of properties for the pie chart wedges. | wedgeprops={'linewidth': 1, 'edgecolor': 'white'} |

# %%
cars=['BMW','AUDI','PORSHE','LAMBOGHINI','BENZ','FERRARI','DODGE']
sales=[20,25,35,47,15,21,16]
plt.pie(sales,labels=cars,shadow=True,autopct='%1.1f%%');

# %% [markdown]
# The plt.subplots() Function
# plt.subplots() is the recommended way to create a figure and a set of subplots. It returns a tuple containing the Figure object and an Axes object or an array of Axes objects.
#
# import matplotlib.pyplot as plt
#
# # Create a figure with a single subplot
#
# fig, ax = plt.subplots()
#
# # Create a figure with 2 rows and 1 column of subplots
#
# fig, axs = plt.subplots(2, 1)
#
# # Create a figure with 2 rows and 2 columns of subplots
#
# fig, axs = plt.subplots(2, 2)
#
# fig: The Figure object, which acts as the top-level container for all plot elements. ax or axs: The Axes object(s), which represent the individual plots within the figure. You call plotting methods like plot(), scatter(), or bar() on these objects.
#
# Accessing Subplots
# When you create multiple subplots, plt.subplots() returns an array of Axes objects. You can access individual subplots using array indexing.

# %% [markdown]
# ### Key Arguments of plt.subplots()
#
# | Argument | Description | Example |
# | :--- | :--- | :--- |
# | nrows | Number of rows of subplots. | nrows=2 |
# | ncols | Number of columns of subplots. | ncols=2 |
# | figsize | A tuple (width, height) in inches. | figsize=(10, 8) |
# | sharex | If True, all subplots will share the same x-axis. | sharex=True |
# | sharey | If True, all subplots will share the same y-axis. | sharey=True |
# | subplot_kw | A dictionary of keyword arguments passed to add_subplot. | subplot_kw={'facecolor': 'lightgray'} |

# %%
fig,ax=plt.subplots(1,3,figsize=(14,4))

ax[0].plot(month,visits,'o-',color='green')
ax[0].plot(month,conversion_rates,'s--',color='orange')
ax[0].set_title('Subscribers')

ax[1].bar(months,visits,color='green')
ax[2].barh(month,visits,color='black',edgecolor='orange')
plt.suptitle('Subplots')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Seaborn

# %% [markdown]
# ### Box plot
#
# To create a box plot, you typically specify the data for the y-axis (the continuous variable) and optionally the x-axis (the categorical variable for grouping).
#
# python
#
# import seaborn as sns
#
# sns.boxplot(y=data)
#
# sns.boxplot(x=category, y=data)
#
#
#   - x: The categorical data for grouping.
#   - y: The continuous data to be plotted.
#   - data: The pandas DataFrame containing the data.
#
# -----
#
# ### Key Arguments and Values
#
#
# | Argument | Description | Common Values & Examples |
# | :--- | :--- | :--- |
# | *x, y* | The columns to be plotted from the data DataFrame. | x='Region', y='Sales' |
# | *hue* | A categorical variable that will determine the colors of the plot elements. | hue='Region' to color boxes by region. |
# | *orient* | The orientation of the plot. | 'v' for vertical (default) or 'h' for horizontal. |
# | *color* | A single color for all the boxes. | color='lightblue', 'g' |
# | *palette* | A color palette for different hue levels. | 'viridis', 'Set2', 'pastel' |
# | *width* | The width of the boxes. | A float between 0 and 1. width=0.6 |
# | *showfliers*| If False, outliers will not be shown. | A boolean. showfliers=False |
# | *notch* | If True, creates a notch at the median for a confidence interval. | A boolean. notch=True |

# %%
import pandas as pd
data = {
    'Age': [30, 45, 28, 52, 35, 40, 29, 38, 48, 33],
    'Job_Satisfaction': ['High', 'Medium', 'High', 'Low', 'High', 'Medium', 'High', 'Low', 'High', 'Medium'],
    'Years_at_Company': [5, 10, 2, 20, 7, 15, 3, 12, 18, 6],
    'Monthly_Income': [6000, 8500, 4500, 10000, 7200, 9500, 5000, 8000, 11000, 7000],
    'Attrition': ['No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No']
}

df2 = pd.DataFrame(data)

sns.boxplot(data = df2, x='Attrition', y='Years_at_Company', palette='pastel')
# Out:
# /tmp/ipython-input-2372849167.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = df2, x='Attrition', y='Years_at_Company', palette='pastel')
# <Axes: xlabel='Attrition', ylabel='Years_at_Company'>

# %% [markdown]
# #KDE Plot

# %% [markdown]
# A *Kernel Density Estimate (KDE) plot* is a way of visualizing the distribution of a continuous variable. It's a smoothed version of a histogram that uses a continuous curve instead of bars, providing a clearer picture of the data's probability density.
#
# ### Key Features of a KDE Plot
#
#   * *Smoothed Representation:* Unlike a histogram, which uses discrete bins, a KDE plot uses a kernel function (typically a Gaussian) to estimate the probability density at every point. This results in a smooth curve that's easier to interpret.
#   * *Peak and Valleys:* The peaks of the curve indicate where data points are most concentrated, while the valleys show where data points are less frequent.
#   * *Area under the Curve:* The total area under a KDE curve is equal to 1, representing 100% of the probability. The height of the curve at any given point is a measure of the probability density at that value.

# %% [markdown]
# ### When to Use a KDE Plot
#
# KDE plots are excellent for:
#
#   * Visualizing the shape of a distribution.
#   * Identifying multimodality (multiple peaks).
#   * Comparing the distributions of multiple variables or groups on the same axes.
#
# The main function for creating a KDE plot in Python is seaborn.kdeplot().
#
# ### seaborn.kdeplot() Syntax and Arguments
#
# The most common way to use seaborn.kdeplot() is to provide the data for the plot.
#
# python
#
#
# import seaborn as sns
#
# sns.kdeplot(x=data, **kwargs)
#
#
#   * x: The continuous data to be plotted. You can also use y for a vertical plot.
#   * data: The DataFrame containing the data.
#
# -----

# %% [markdown]
# ### Key Arguments and Values
#
# | Argument | Description | Common Values & Examples |
# | :--- | :--- | :--- |
# | *x, y* | The columns to be plotted from the data DataFrame. | x='Sales' |
# | *hue* | A categorical variable that will determine the colors for different distributions. | hue='Region' to compare sales by region. |
# | *fill* | If True, fills the area under the curve with color. | A boolean. fill=True |
# | *palette*| A color palette for different hue levels. | 'viridis', 'Set2', 'pastel' |
# | *bw_adjust*| Adjusts the "smoothness" of the curve. A higher value makes the plot smoother. | A float. bw_adjust=0.5 (less smooth), bw_adjust=2.0 (more smooth) |
# | *common_norm*| If True, normalizes the density for each hue level across the entire dataset. | A boolean. common_norm=True |
# | *alpha* | The transparency of the filled area. | A float between 0 and 1. alpha=0.6 |

# %%
sns.kdeplot(steps, fill=True, color='purple')
# Out:
# <Axes: ylabel='Density'>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# A *pairplot* is a powerful Seaborn visualization tool that plots pairwise relationships in a dataset. It creates a grid of plots where each variable in the dataset is plotted against every other variable. This allows you to quickly visualize correlations, distributions, and potential relationships within your data.
#
# ### Anatomy of a Pairplot
#
# A pairplot consists of two main types of plots:
#
#   * *Scatter Plots: The off-diagonal plots in the grid are **scatter plots*. Each scatter plot shows the relationship between two different variables. You can easily spot positive, negative, or no correlation between variable pairs.
#   * *Distribution Plots: The plots on the diagonal are **distribution plots* (typically histograms or KDE plots). They show the distribution of each individual variable, providing a view of its central tendency, spread, and shape.
#
# ### Key Arguments and Values
#
# The main function is seaborn.pairplot().
#
# | Argument | Description | Common Values & Examples |
# | :--- | :--- | :--- |
# | *data* | The DataFrame to be plotted. | data=df |
# | *hue* | A categorical variable that will determine the color of the plot points. | hue='Region' |
# | *kind* | The type of plot to use on the off-diagonal subplots. | 'scatter' (default), 'reg' (for a regression line), 'kde' |
# | *diag_kind* | The type of plot to use on the diagonal subplots. | 'hist' (default), 'kde' |
# | *vars* | A list of column names to plot. Useful for plotting a subset of variables. | vars=['Age', 'Sales'] |
# | *palette* | A color palette for the different hue levels. | 'viridis', 'Set2', 'pastel' |
# | *corner* | If True, only plots the lower triangle of the pairplot. | corner=True |

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species', palette='viridis')

# %% [markdown]
# * To create a correlation matrix and a heatmap in Python, you can use pandas and Seaborn. The correlation matrix is a table that shows the correlation coefficients between variables, while a heatmap is a graphical representation of this matrix that uses color intensity to make the correlations easier to interpret.
#
#
# 1. Calculate the Correlation Matrix
# First, you need to calculate the correlation matrix from your DataFrame using the .corr() method. By default, this uses the Pearson correlation coefficient.
#
# * The output will be a new DataFrame showing the correlation of each numerical column with every other numerical column. A value close to 1 indicates a strong positive correlation, -1 indicates a strong negative correlation, and 0 indicates no correlation.
#
# 2. Create a Heatmap
# A heatmap is a graphical representation of data where values in a matrix are represented as colors. It's especially useful for visualizing a correlation matrix to quickly identify strong or weak relationships between variables.
#
# * Basic Syntax
# The most common way to create a heatmap is by passing a 2D dataset, like a correlation matrix from a pandas DataFrame.
#
# import seaborn as sns
#
# sns.heatmap(data, **kwargs)
#
# * data: A 2D array or pandas DataFrame containing the values to be plotted.

# %% [markdown]
# Argument      | Description                                         | Common Values & Examples
# ------------- | --------------------------------------------------- | -------------------------
# annot         | Display data values in each cell                    | True or False → annot=True
# fmt           | Format string for annotations                       | '.2f' for floats, 'd' for integers
# cmap          | Colormap for cell shading                           | 'coolwarm', 'viridis', 'plasma'
# linewidths    | Width of lines between cells                        | Float → linewidths=0.5
# linecolor     | Color of the dividing lines                         | Color name → linecolor='white'
# cbar          | Show color bar beside the heatmap                   | True or False → cbar=True
# vmin, vmax    | Set min and max values for colormap scale           | Floats → vmin=-1, vmax=1
# square        | Make cells square-shaped                            | True or False → square=True

# %%
num_cols = iris.select_dtypes(include=['number'])
corr = num_cols.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr, annot=True, cmap='turbo')
# Out:
# <Axes: >

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'berlin_r', 'managua_r', 'vanimo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r', 'grey_r', 'gist_grey_r', 'gist_yerg_r', 'Grays_r', 'rocket', 'rocket_r', 'mako', 'mako_r', 'icefire', 'icefire_r', 'vlag', 'vlag_r', 'flare', 'flare_r', 'crest', 'crest_r']

# %%
### Example with a DataFrame

#This example uses a sample DataFrame to show how pairplot can reveal relationships between sales, marketing spend, and region.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Sales': [100, 120, 150, 130, 180, 200],
    'Marketing_Spend': [5, 6, 8, 7, 9, 10],
    'Region': ['North', 'North', 'South', 'South', 'North', 'South']
}
df = pd.DataFrame(data)

# Create a basic pairplot
sns.pairplot(df, hue='Region', kind='scatter', diag_kind='kde')
plt.suptitle('Pairwise Relationships of Sales and Marketing Spend', y=1.02)
plt.show()
